# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52051/23CSBTB39-40/blob/main/SML_A7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1:
#
# https://www.kaggle.com/datasets/rohankayan/years-of-experience-and-salary-datasetLinks to an external site.
#
#
#
# From the above data:
#
# Read the data with pandas and find features and target variables
# Plot a graph between features and target
# Find Best fit line using linear regression.
# FInd MSE, MAE, for test size (20,25)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Step 1: Read the data
data = pd.read_csv('Salary_Data.csv')

# %%
# Step 2: Extract features and target
X = data[['YearsExperience']]
y = data['Salary']

# %%
# Step 3: Create a linear regression model and fit it
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Step 4: Predict values using the model (best fit line)
y_pred = model.predict(X)

# %%
# Step 5: Plot the graph
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', label='Best fit line')
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Questions 2:
#
# Read the data with pandas and find features and target variables
# Plot a graph between features and target
# Find Best fit line using linear regression.
# Fond MSE , MAE for test size (20,30)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
data_dict = {
 'Feature 1': [1.2, 2.4, 3.5, 4.1, 1.9, 3.7, 2.1, 3.3, 2.8, 4.0],
 'Feature 2': [2.3, 1.9, 2.7, 3.0, 2.8, 2.5, 3.2, 2.4, 3.1, 3.3],
 'Feature 3': [3.1, 2.8, 1.5, 3.6, 2.5, 1.9, 2.2, 3.0, 1.8, 2.7],
 'Feature 4': [4.2, 3.5, 2.9, 4.8, 3.2, 4.0, 4.1, 4.5, 3.6, 4.9],
 'Target': [15.6, 13.1, 12.4, 18.2, 14.1, 16.0, 14.5, 17.3, 14.9, 19.2]

 }
data = pd.DataFrame(data_dict)
X = data[['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4']]
y = data['Target']


plt.scatter(X['Feature 1'], y, color='blue')
plt.title('Feature 1 vs Target')
plt.xlabel('Feature 1')
plt.ylabel('Target (Y)')
plt.show()
test_sizes = [0.2, 0.3]
for test_size in test_sizes:
    print(f"\nTest size: {int(test_size * 100)}%")
    X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=42)
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual')
    plt.scatter(range(len(y_test)), y_pred, color='red', label='Predicted')
    plt.title(f'Actual vs Predicted (Test Size: {int(test_size * 100)}%)')
    plt.xlabel('Data Points')
    plt.ylabel('Target (Y)')
    plt.legend()
    plt.show()

    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    print(f"MSE: {mse}")
    print(f"MAE: {mae}")
# Out:
# Test size: 20%
# MSE: 1.2020186561889346
# MAE: 1.0313248712002014
#
# Test size: 30%
# MSE: 0.8283376869765737
# MAE: 0.8651731636820733
